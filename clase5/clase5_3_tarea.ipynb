# %% [markdown]
# ## Tarea: Condicionales y Librerías Básicas
#
# Resuelve los siguientes ejercicios utilizando los conceptos vistos en clases. Escribe tu código en las celdas asignadas debajo de cada enunciado.

# %% [markdown]
# ### Ejercicio 1: Suma aleatoria contra el reloj
#
# **Descripción del problema:**
# Crea un programa que importe las librerías `random` y `time`. El programa debe generar dos números enteros aleatorios (entre 1 y 10) y mostrarlos al usuario como un problema de suma matemática. Mide el tiempo exacto que tarda el usuario en ingresar su respuesta y muestra ese tiempo en segundos en la pantalla.
#
# **Ejemplo de ejecución esperada:**
# ```text
# Resuelve la siguiente suma: 4 + 8
# Tu respuesta: 12
# Te demoraste 3.45 segundos en responder.
# ```

# %%
# Escribe aquí tu código para el Ejercicio 1

# %% [markdown]
# ### Ejercicio 2: Ordenamiento numérico manual
#
# **Descripción del problema:**
# Solicita al usuario que ingrese tres números diferentes. Utilizando únicamente sentencias condicionales (`if`, `elif`, `else`), determina el orden de los números y muéstralos en pantalla de mayor a menor. No utilices funciones de ordenamiento integradas de Python.
#
# **Ejemplo de ejecución esperada:**
# ```text
# Ingrese el primer número: 7
# Ingrese el segundo número: 2
# Ingrese el tercer número: 9
#
# Los números ordenados de mayor a menor son: 9, 7, 2
# ```

# %%
# Escribe aquí tu código para el Ejercicio 2

# %% [markdown]
# ### Ejercicio 3: Adivina el número
#
# **Descripción del problema:**
# Crea un programa que genere un número secreto aleatorio entre 1 y 5. El usuario tendrá un máximo de 3 intentos para adivinar el número.
#
# Si el usuario acierta, el programa debe felicitarlo y detenerse. Si falla, debe indicarle que es incorrecto y pedir el siguiente intento. Si se acaban los 3 intentos sin éxito, el programa debe revelar el número secreto al final.
#
# **Ejemplo de ejecución esperada:**
# ```text
# Adivina el número secreto (entre 1 y 5). Tienes 3 intentos.
# Intento 1: 3
# Incorrecto.
# Intento 2: 4
# Incorrecto.
# Intento 3: 2
# Felicidades. Adivinaste el número.
# ```

# %%
# Escribe aquí tu código para el Ejercicio 3
