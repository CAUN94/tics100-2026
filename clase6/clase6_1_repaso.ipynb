# %% [markdown]
# ## Repaso
#
# Resuelve los siguientes ejercicios utilizando la estructura `if`, `elif` y `else`.

# %% [markdown]
# ### Ejercicio 1: Saludo Personalizado
#
# **Descripción del problema:**
# Pide al usuario que ingrese su nombre y su género. Las opciones de género deben ser "Masculino", "Femenino" o "Prefiero no decirlo". Utiliza condicionales para mostrar un saludo correcto.
#
# - Si ingresa Masculino, debe decir: Bienvenido [Nombre]
# - Si ingresa Femenino, debe decir: Bienvenida [Nombre]
# - Si ingresa Prefiero no decirlo, debe decir: Hola [Nombre]
#
# **Ejemplo de ejecución esperada:**
# ```text
# Ingrese su nombre: Alex
# Ingrese su género (Masculino / Femenino / Prefiero no decirlo): Femenino
# Bienvenida Alex
# ```

# %%
# Escribe aquí tu código para el Ejercicio 1

# %% [markdown]
# ### Ejercicio 2: Escalera de Números
#
# **Descripción del problema:**
# Solicita al usuario que ingrese un número entero. El programa debe evaluar ese número e imprimir en pantalla los mensajes correspondientes si es que el número supera las barreras del 3, 7, 12 y 20.
#
# **Ejemplo de ejecución esperada:**
# ```text
# Ingrese un número: 8
# mayor a 3
# mayor a 7
# ```

# %%
# Escribe aquí tu código para el Ejercicio 2

# %% [markdown]
# ### Ejercicio 3: Sistema de Eximición
#
# **Descripción del problema:**
# Crea un programa que evalúe si un estudiante se exime del examen final. El programa debe pedir las notas de 3 pruebas, las cuales tienen las siguientes ponderaciones:
# - Prueba 1: 30%
# - Prueba 2: 30%
# - Prueba 3: 40%
#
# La regla para eximirse es tener un promedio final igual o superior a 5.0. Sin embargo, existe una condición estricta: si el alumno obtiene una nota inferior a 4.0 en la tercera prueba, pierde automáticamente el derecho a eximirse, sin importar su promedio final.
#
# El programa debe calcular el promedio ponderado e imprimir si el alumno está eximido o debe rendir el examen.
#
# **Ejemplo de ejecución esperada:**
# ```text
# Ingrese la nota de la Prueba 1: 6.0
# Ingrese la nota de la Prueba 2: 5.5
# Ingrese la nota de la Prueba 3: 3.8
#
# Promedio final: 4.97
# Resultado: Debes rendir el examen final. (Nota inferior a 4.0 en la última prueba)
# ```

# %%
# Escribe aquí tu código para el Ejercicio 3
