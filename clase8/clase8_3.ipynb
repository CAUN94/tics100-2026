# %% [markdown]
# # Clase 8: Reforzamiento `for` y `while`
#
# Estas dos materias (los condicionales y los ciclos) son **fundamentales** para todo lo que viene en el futuro. Son la base sobre la cual se construye cualquier programa, aplicación o videojuego avanzado. Entender cómo repetir código y tomar decisiones dinámicas es la habilidad más importante en programación, por lo que seguiremos haciendo ejercicios combinados de esto hasta que lo domines por completo.

# %% [markdown]
# ### 1. Auditoría de Contraseñas
#
# **Descripción:** Tienes una lista predefinida con varias contraseñas ingresadas por los usuarios. Recorre la lista y haz una revisión del largo de cada una para determinar cuáles no son seguras. Se establece que una contraseña con menos de 6 caracteres se considera poco segura.
#
# **Hint:** Recuerda que la función `len(texto)` entrega la cantidad exacta de caracteres que tiene un *string*.
#
# **Ejemplo de ejecución:**
# ```text
# Contraseña 1 -> No segura
# Contraseña 2 -> Segura
# Contraseña 3 -> Segura
# ```

# %%
contrasenas = ["hola", "admin123", "12345", "seguridadMaxima", "qwerty"]

# Escribe tu código aquí

# %% [markdown]
# ### 2. Multiplicador Aleatorio
#
# **Descripción:** Importa la librería `random`. Crea un programa que comience con una lista de números enteros. Usa un ciclo para tomar cada valor de la lista y multiplicarlo por un número elegido totalmente al azar dentro del siguiente conjunto específico: `[10, 20, 30, 40, 50]`. Ve mostrando la operación en pantalla, guarda estos nuevos resultados multiplicados en una lista completamente nueva y muéstrala al finalizar.
#
# **Ejemplo de ejecución:**
# ```text
# Lista original: [1, 3, 2]
# 1 por 40 -> 40
# 3 por 50 -> 150
# 2 por 20 -> 40
# Lista Nueva: [40, 150, 40]
# ```

# %%
import random
numeros = [1, 3, 2, 5, 8]

# Escribe tu código aquí

# %% [markdown]
# ### 3. Cálculo de Ingresos por Producto
#
# **Descripción:** En un sistema de inventario tienes 3 listas paralelas. Todas tienen exactamente la misma cantidad de elementos (es decir, `len(productos) = x`, `len(cantidad) = x`, `len(valor) = x`):
#
# ```python
# productos = ["Manzanas", "Peras", "Naranjas"]
# cantidad = [50, 30, 40]
# valor = [200, 1500, 200]
# ```
#
# Usando un ciclo `for`, vincula la información de las tres listas para calcular el ingreso total que genera cada producto (es decir, multiplicando su cantidad disponible por su valor unitario) y haz que por pantalla salga el resultado con el valor final.
#
# **Hint:** Usa `for i in range(len(productos)):` para generar un índice maestro que te permita acceder a la misma posición en las tres listas simultáneamente.
#
# **Ejemplo de ejecución:**
# ```text
# El producto Manzanas genera un valor de 10000
# El producto Peras genera un valor de 45000
# El producto Naranjas genera un valor de 8000
# ```

# %%
productos = ["Manzanas", "Peras", "Naranjas"]
cantidad = [50, 30, 40]
valor = [200, 1500, 200]

# Escribe tu código aquí

# %% [markdown]
# ### 4. Adivinador Aleatorio Inverso
#
# **Descripción:** Pídele al usuario que ingrese un número entre 1 y 10. Usando un ciclo `while` y la librería `random`, haz que el computador genere números aleatorios entre 1 y 10 repetidamente **hasta** que encuentre exactamente el valor que el usuario pidió. El programa debe ir guardando todos los números que se crearon dentro de una lista, y mostrar esa lista al final del proceso junto con un mensaje de éxito que incluya el número.
#
# **Ejemplo de ejecución:**
# ```text
# Ingrese un número entre 1 y 10: 7
# Buscando...
# ¡El computador encontró tu número: 7!
# Números generados antes de adivinar: [3, 9, 2, 5, 7]
# ```

# %%
import random

# Escribe tu código aquí

# %% [markdown]
# ### 5. Descomposición en Potencias de 10
#
# **Descripción:** Crea un programa que le pida al usuario ingresar un número entero (de máximo 5 cifras). Utilizando ciclos, el sistema debe descomponer visualmente la cantidad ingresada en potencias de 10, imprimiendo por pantalla los decenas de miles, miles, cientos, decenas y unidades desglosados uno debajo del otro.
#
# **Ejemplo de ejecución:**
# ```text
# Ingrese un número (máximo 5 cifras): 4321
# 1000
# 1000
# 1000
# 1000
# 100
# 100
# 100
# 10
# 10
# 1
# ```

# %%
# Escribe tu código aquí
