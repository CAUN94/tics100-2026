# %% [markdown]
# ### Ejercicio: Descubriendo la Letra Oculta
#
# **Enunciado:** Tienes una matriz de 3x3 que contiene diferentes letras. Tu objetivo es imprimir por pantalla únicamente la letra "Z" accediendo a su coordenada exacta.

# %%
letras = [
    ['A', 'B', 'C'],
    ['D', 'Z', 'F'],
    ['G', 'H', 'I']
]

# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio: Mostrar una Fila Específica
#
# **Enunciado:** Un sistema guarda las notas de 3 alumnos. Cada alumno es una fila. Imprime por pantalla la lista completa de notas del segundo alumno (el de la mitad).

# %%
notas_alumnos = [
    [4.0, 5.5, 6.0],
    [7.0, 6.8, 6.5],
    [3.5, 4.2, 5.0]
]

# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio: Extracción de Esquinas
#
# **Enunciado:** Extrae los 4 números que se encuentran en las esquinas de esta matriz de 3x3 y muéstralos juntos en un solo `print()`.

# %%
tablero = [
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
]

# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio: Cuadrícula de Asteriscos
#
# **Enunciado:** Utiliza un doble `for` para imprimir una cuadrícula de 3 filas y 4 columnas formada únicamente por asteriscos (`*`).
#
# **Hint:** Usa `end=" "` en el `print` interior para que los asteriscos queden uno al lado del otro, y un `print()` vacío en el ciclo exterior para saltar de línea.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio: Triángulo de Asteriscos Dinámico
#
# **Enunciado:** Dibuja un triángulo rectángulo escalonado de 5 pisos utilizando asteriscos (`*`). El primer piso debe tener 1 asterisco, el segundo 2, y así sucesivamente.
#
# **Hint:** Utiliza la estrategia del rango dinámico. Haz que el ciclo interior recorra desde `1` hasta el valor actual del ciclo exterior (`i + 1`).

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio: Escalera Numérica Horizontal
#
# **Enunciado:** Dibuja un triángulo de 5 pisos donde los números avancen en secuencia en cada piso.
# Piso 1: `1`
# Piso 2: `1 2`
# Piso 3: `1 2 3`...
#
# **Hint:** Nuevamente usa rango dinámico, pero esta vez la variable que debes imprimir en pantalla es la del ciclo interior (`j`).

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio: Escalera Numérica Vertical (Pisos Repetidos)
#
# **Enunciado:** Dibuja un triángulo de 5 pisos donde el mismo número se repita hacia el lado dependiendo del piso.
# Piso 1: `1`
# Piso 2: `2 2`
# Piso 3: `3 3 3`...
#
# **Hint:** Usa rango dinámico, pero la variable a imprimir en pantalla debe ser la de la fila (`i`), no la de la columna.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio: El Cuadrado Hueco
#
# **Enunciado:** Dibuja un cuadrado de tamaño 5x5 usando asteriscos, pero que esté vacío por dentro. Solo deben dibujarse los bordes.
#
# **Hint:** Imprime un asterisco únicamente si te encuentras en la primera fila, en la última fila, en la primera columna o en la última columna usando un `if` combinado con `or`. De lo contrario, imprime un doble espacio en blanco `"  "`.

# %%
# Escribe tu código aquí
