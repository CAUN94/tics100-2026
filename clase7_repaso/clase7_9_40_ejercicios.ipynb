# %% [markdown]
# # Guía de Ejercicios: Progresión Lógica y Estructuras Iterativas
#
# Esta guía está diseñada para desarrollar tu lógica de programación paso a paso. Para cada ejercicio encontrarás:
# 1. **Versión (simple):** Resolución manual o para un caso único.
# 2. **Versión (con ciclos):** Evolución del problema usando `for` o `while`.
#
# **REGLA DE ORO ESTRICTA:** Queda totalmente prohibido el uso de las instrucciones `break`, `continue` o `pass`. Todo el control del flujo, pausas y salidas de los ciclos se maneja exclusivamente mediante lógica booleana, banderas de estado y condiciones `if/else`.

# %% [markdown]
# ## Bloque 1: Repetición y Operaciones Básicas

# %% [markdown]
# ### Eco del nombre
# **Enunciado:** Se requiere un programa que repita el nombre del usuario en pantalla.
# #### Eco del nombre (simple)
# Pide tu nombre usando `input()` e imprímelo una sola vez.

# %%
# 1. Pide el nombre al usuario usando input() y guardalo en una variable

# 2. Imprime un mensaje concatenando el texto introductorio y la variable separada por una coma

# %% [markdown]
# #### Eco del nombre (con ciclos)
# Usa un `for` con `range(5)` para automatizar la repetición del nombre 5 veces.

# %%
# 1. Pide el nombre al usuario

# 2. Crea un ciclo for que se repita 5 veces usando range(5)

    # 3. Dentro del ciclo, imprime el nombre concatenando con comas

# %% [markdown]
# ### Listado de elementos
# **Enunciado:** Mostrar elementos guardados de una colección.
# #### Listado de elementos (simple)
# Dada una lista de 3 animales, imprime el primero y el segundo elemento manualmente.

# %%
# 1. Crea una lista con 3 animales (ej: ["gato", "perro", "loro"])

# 2. Imprime el primer animal accediendo al indice 0

# 3. Imprime el segundo animal accediendo al indice 1

# %% [markdown]
# #### Listado de elementos (con ciclos)
# Usa un `for` para recorrer la lista e imprimir todos los animales uno por uno.

# %%
# 1. Crea la misma lista con 3 animales

# 2. Usa un ciclo for iterando directamente sobre la lista (for animal in lista:)

    # 3. Imprime la variable iteradora en cada vuelta del ciclo

# %% [markdown]
# ### Suma de dos números
# **Enunciado:** Sumar valores matemáticos.
# #### Suma de dos números (simple)
# Pide dos números, súmalos y muestra el resultado.

# %%
# 1. Pide el primer numero, conviertelo a int() y guardalo en una variable

# 2. Pide el segundo numero, conviertelo a int() y guardalo en una variable

# 3. Suma ambos numeros y guarda el resultado en una nueva variable

# 4. Imprime un texto descriptivo junto al resultado de la suma

# %% [markdown]
# #### Suma de dos números (con ciclos)
# Usa un `for` que se repita 3 veces. En cada vuelta, pide dos números y muestra su suma.

# %%
# 1. Crea un ciclo for que itere 3 veces usando range(3)

    # 2. Dentro del ciclo, pide el primer numero entero
    
    # 3. Pide el segundo numero entero
    
    # 4. Suma ambos numeros
    
    # 5. Imprime el resultado de esa suma parcial

# %% [markdown]
# ### Presentación personal
# **Enunciado:** Mostrar información personal unida en una sola línea.
# #### Presentación personal (simple)
# Pide nombre y edad. Imprime un mensaje que los una.

# %%
# 1. Pide el nombre al usuario

# 2. Pide la edad al usuario

# 3. Imprime el mensaje uniendo el texto estatico y las variables usando comas

# %% [markdown]
# #### Presentación personal (con ciclos)
# Usa un `for` para pedir los datos de 2 personas distintas y presentarlas.

# %%
# 1. Crea un ciclo for que se repita 2 veces

    # 2. Adentro, pide el nombre
    
    # 3. Pide la edad
    
    # 4. Imprime la presentacion

# %% [markdown]
# ### Contador de palabras específicas
# **Enunciado:** Contar cuántas veces aparece la palabra "gato" en unos datos.
# #### Contador de palabras específicas (simple)
# Pide una palabra al usuario. Si es "gato", guarda un 1 en un contador manual, si no, guarda un 0.

# %%
# 1. Pide al usuario que ingrese un animal

# 2. Crea una variable contador y dale el valor inicial de 0

# 3. Usa un if para verificar si la palabra ingresada es igual a "gato"

    # 4. Si es igual, asigna el valor 1 al contador

# 5. Imprime cuantas veces aparecio usando la variable contador

# %% [markdown]
# #### Contador de palabras específicas (con ciclos)
# Dada una lista, recorre con un `for` y cuenta cuántas veces aparece "gato" usando un `if` y un contador.

# %%
# 1. Crea una lista con varios animales, incluyendo multiples ocurrencias de "gato"

# 2. Crea una variable contador iniciada en 0

# 3. Recorre la lista con un ciclo for

    # 4. Usa un if para verificar si el animal de la iteracion actual es igual a "gato"
    
        # 5. Si lo es, sumale 1 al contador (contador = contador + 1)

# 6. Fuera del ciclo, imprime el total del contador

# %% [markdown]
# ### Primer elemento de listas
# **Enunciado:** Obtener la cabecera de las colecciones.
# #### Primer elemento de listas (simple)
# Dada una lista, imprime solo su índice `0`.

# %%
# 1. Crea una lista estatica con 3 nombres

# 2. Imprime unicamente el primer nombre utilizando el indice [0]

# %%
# 1. Crea una lista principal que contenga listas internas (ej: [ ["Ana", 20], ["Juan", 30] ])

# 2. Recorre la lista principal usando un ciclo for

    # 3. Dentro del ciclo, imprime el indice [0] de la sublista que estas iterando

# %% [markdown]
# ### Filtro de números pares
# **Enunciado:** Detectar si un número es par usando matemática.
# #### Filtro de números pares (simple)
# Pide un número y usa el módulo (`% 2 == 0`) con un `if` para indicar si es par.

# %%
# 1. Pide un numero entero al usuario

# 2. Usa un if para comprobar si el resto de dividirlo por 2 es igual a 0

    # 3. Si se cumple, imprime que es par

# 4. Usa un bloque else para atrapar el caso contrario e imprimir que es impar

# %% [markdown]
# #### Filtro de números pares (con ciclos)
# Recorre una lista de números con un `for`. Dentro, usa el `if` para imprimir únicamente los que son pares.

# %%
# 1. Crea una lista con varios numeros enteros variados

# 2. Recorre la lista entera usando un ciclo for

    # 3. Usa el if para verificar el operador modulo en el numero de la vuelta actual
    
        # 4. Si el numero es par, muestralo por pantalla. (Si no es par, no hagas nada)

# %% [markdown]
# ### Generador de Correos
# **Enunciado:** Crear correos institucionales automáticamente.
# #### Generador de Correos (simple)
# Pide un nombre y concaténalo con la extensión "@uai.cl" usando coma.

# %%
# 1. Pide el nombre de pila al usuario

# 2. Imprime el nombre y el dominio juntos en la misma linea

# %% [markdown]
# #### Generador de Correos (con ciclos)
# Crea una lista con nombres. Recórrela con un `for` y en cada iteración imprime el correo.

# %%
# 1. Crea una lista con varios nombres (strings)

# 2. Configura un for que itere sobre la lista de nombres

    # 3. En cada iteracion imprime el nombre actual acompanado del dominio "@uai.cl"

# %% [markdown]
# ### Repetición de caracteres
# **Enunciado:** Mostrar varios símbolos iguales.
# #### Repetición de caracteres (simple)
# Imprime una línea de 5 asteriscos en un solo print.

# %%
# 1. Escribe un unico print que contenga los 5 asteriscos "* * * * *"

# %% [markdown]
# #### Repetición de caracteres (con ciclos)
# Usa un `for` iterando 5 veces para imprimir un asterisco en diferentes líneas.

# %%
# 1. Usa un ciclo for con range(5)

    # 2. En el interior del ciclo, imprime un solo "*" por vuelta

# %% [markdown]
# ### Lista en reversa
# **Enunciado:** Acceder a los datos de atrás hacia adelante.
# #### Lista en reversa (simple)
# Dada una lista de 3 elementos, imprime el último usando el índice negativo `[-1]`.

# %%
# 1. Crea una lista con tres datos numericos

# 2. Usa el indice [-1] en un print para mostrar el elemento final de la lista

# %% [markdown]
# #### Lista en reversa (con ciclos)
# Dada una lista, recórrela usando índices con un `for` y la función `range` avanzando en paso negativo.

# %%
# 1. Recrea la lista con tres datos

# 2. Usa un for con range(inicio, fin, paso) donde inicio es 2, fin es -1 (para incluir al 0) y paso es -1

    # 3. Imprime el contenido de la lista utilizando la variable iteradora del ciclo como indice

# %% [markdown]
# ## Bloque 2: Rango y Secuencias numéricas

# %% [markdown]
# ### Conteo del 1 al 10
# **Enunciado:** Mostrar una secuencia de números continuos.
# #### Conteo del 1 al 10 (simple)
# Imprime los números 1, 2 y 3 usando tres sentencias `print()` consecutivas.

# %%
# 1. Escribe el primer print con el numero 1

# 2. Escribe el segundo print con el numero 2

# 3. Escribe el tercer print con el numero 3

# %% [markdown]
# #### Conteo del 1 al 10 (con ciclos)
# Usa `for numero in range(1, 11):` para generar e imprimir automáticamente la secuencia del 1 al 10. (El límite superior no se incluye).

# %%
# 1. Construye el for con el range comenzando en 1 y terminando en 11

    # 2. Imprime la variable iteradora

# %% [markdown]
# ### Salto de 5 en 5
# **Enunciado:** Contar números usando un incremento mayor a 1.
# #### Salto de 5 en 5 (simple)
# Define una variable en 5. Luego imprímela, súmale 5 e imprímela de nuevo.

# %%
# 1. Define una variable con el numero 5

# 2. Imprime la variable

# 3. Sumale 5 a la misma variable (variable = variable + 5)

# 4. Vuelve a imprimirla para ver su actualizacion

# %% [markdown]
# #### Salto de 5 en 5 (con ciclos)
# Usa los tres parámetros de `range(inicio, fin, paso)`. Empieza en 5, termina antes del 25 saltando de 5 en 5.

# %%
# 1. Crea el for con range usando tres parametros (5, 25, 5)

    # 2. Imprime el valor de tu variable de iteracion dentro del bloque

# %% [markdown]
# ### Cuenta Regresiva
# **Enunciado:** Retroceder secuencialmente hacia cero.
# #### Cuenta Regresiva (simple)
# Escribe variables bajando e imprímelas.

# %%
# 1. Escribe prints manuales para hacer la cuenta atras 3, 2, 1

# %% [markdown]
# #### Cuenta Regresiva (con ciclos)
# Para retroceder, usa `range(10, 0, -1)`. Muestra los números bajando de a 1.

# %%
# 1. Declara el for usando range y los tres parametros para avanzar negativamente

    # 2. Imprime la variable del ciclo en cada paso para ver la cuenta regresiva en pantalla

# %% [markdown]
# ### Pares en rango dinámico
# **Enunciado:** Mostrar pares dentro de un intervalo ingresado por el usuario.
# #### Pares en rango dinámico (simple)
# Pide un número y asume que ese es tu tope para evaluar manualmente el número anterior.

# %%
# 1. Pide al usuario que ingrese un numero limite

# 2. Crea una variable evaluado restandole 1 a ese limite

# 3. Comprueba usando modulo si la nueva variable 'evaluado' es par

    # 4. De ser asi, imprimelo

# %% [markdown]
# #### Pares en rango dinámico (con ciclos)
# Pide un número límite. Recorre con un `for` desde el 1 hasta ese límite incluido. Usa el `if` para imprimir sólo los pares.

# %%
# 1. Pide un limite superior entero

# 2. Usa un for con range() que vaya desde 1 hasta el limite (incluido sumando +1 al tope)

    # 3. Anida un if que verifique que el numero del bucle actual sea par
    
        # 4. Si aprueba el filtro, muestra ese numero

# %% [markdown]
# ### Serie de Potencias
# **Enunciado:** Desplegar una sucesión multiplicativa.
# #### Serie de Potencias (simple)
# Calcula e imprime manualmente la potencia usando variables.

# %%
# 1. Declara la base como 2

# 2. Crea la variable resultado y haz la multiplicacion iterativa manual (base * base * base)

# 3. Imprime en pantalla

# %% [markdown]
# #### Serie de Potencias (con ciclos)
# Inicia una variable en 1. Usa `range(5)` para ir multiplicándola por 2 en cada vuelta e ir mostrándola (2, 4, 8...).

# %%
# 1. Crea una variable acumulador y dale el valor 1

# 2. Usa for para ejecutar el tramo 5 veces

    # 3. En cada pasada, actualiza acumulador multiplicando su propio valor por 2
    
    # 4. E imprime al final de cada iteracion para ver el crecimiento de la serie

# %% [markdown]
# ### Múltiplos simultáneos
# **Enunciado:** Identificar números que cumplan con la regla de 3 y 5 a la vez.
# #### Múltiplos simultáneos (simple)
# Pide un número y evalúa con un `if` usando `and`.

# %%
# 1. Solicita un numero para ponerlo a prueba

# 2. Abre un if. Verifica que la division por modulo de 3 sea cero AND la de 5 sea cero

    # 3. Muestra un mensaje exitoso si supera la barrera multiple

# 4. En el caso contrario, informa que fallo la prueba de doble validacion

# %% [markdown]
# #### Múltiplos simultáneos (con ciclos)
# Genera un rango del 1 al 30. Evalúa en cada paso la condición múltiple. Si se cumple, imprime el número.

# %%
# 1. Arranca un for recorriendo los numeros entre 1 y 30

    # 2. Utiliza el if anidado con conectores and para validar la divisibilidad simultanea
    
        # 3. Si el digito califica, imprimelo

# %% [markdown]
# ### Tabla de multiplicar
# **Enunciado:** Generar la tabla matemática de una base.
# #### Tabla de multiplicar (simple)
# Imprime de forma manual las multiplicaciones por 1 y por 2.

# %%
# 1. Fija tu variable base, por ejemplo el 5

# 2. Imprime y calcula matematicamente dentro del print la multiplicacion base * 1

# 3. Haz lo mismo para la multiplicacion base * 2

# %% [markdown]
# #### Tabla de multiplicar (con ciclos)
# Pide la base al usuario. Utiliza un `for` de 1 al 10 para imprimir todas las combinaciones.

# %%
# 1. Pide al usuario que base quiere ver

# 2. Usa un range que abarque desde el 1 hasta el 10 (con limite excluyente 11)

    # 3. Crea una variable interna que guarde el resultado de iterador * base
    
    # 4. Forma el print que muestra esteticamente el proceso y la solucion final

# %% [markdown]
# ### Cuadrado de Asteriscos
# **Enunciado:** Dibujar usando ciclos anidados.
# #### Cuadrado de Asteriscos (simple)
# Imprime un bloque manual.

# %%
# 1. Imprime una tira manual de asteriscos "* * *"

# 2. Repite lo mismo debajo

# %% [markdown]
# #### Cuadrado de Asteriscos (con ciclos)
# Usa un `for i` para las filas (ej: 3) y dentro otro `for j` para sumar asteriscos en un texto e imprimir la fila completa.

# %%
# 1. Abre un bucle externo for que manejara la cantidad de lineas que vas a tener (filas)

    # 2. Crea un string vacio en cada pasada inicial llamado texto_fila
    
    # 3. Abre un bucle interno for (para pintar cada columna horizontal)
    
        # 4. Anade un asterisco a la variable string (texto_fila = texto_fila + "* ")
        
    # 5. Estando en el nivel del primer for, e imprime texto_fila antes de la siguiente vuelta general

# %% [markdown]
# ### Escalera de caracteres
# **Enunciado:** Mostrar una secuencia que crece a nivel piramidal.
# #### Escalera de caracteres (simple)
# Imprime los pisos manualmente sumando símbolos.

# %%
# 1. Asigna el simbolo "#" a una variable piso

# 2. Imprimelo por primera vez

# 3. Suma un hashtag adicional al string

# 4. Vuelve a imprimirlo con el tamano aumentado

# %% [markdown]
# #### Escalera de caracteres (con ciclos)
# Usa un `for` que itere 5 veces, sumando en cada vuelta un `#` a una variable base y mostrándola.

# %%
# 1. Crea una string vacia llamada escalera

# 2. Utiliza un for simple de repeticion de 5 tramos

    # 3. Agrega el simbolo "#" concatenando a la escalera existente en memoria
    
    # 4. Imprime el contenido presente

# %% [markdown]
# ### El Enésimo término
# **Enunciado:** Generar una serie matemática a partir de su fórmula.
# #### El Enésimo término (simple)
# Dada la fórmula `3 * n - 2`, calcula el término manual para `n = 2`.

# %%
# 1. Define n = 2 estaticamente

# 2. Crea la variable que desarrolle y sostenga el valor de la operacion (3 * n - 2)

# 3. Muestra ese resultado final

# %% [markdown]
# #### El Enésimo término (con ciclos)
# Recorre un rango de `n` desde 1 hasta 5. Aplica la fórmula e imprime los resultados.

# %%
# 1. Haz que tu variable for sea 'n' y corra un range de 1 a 5

    # 2. Resuelve la ecuacion y guardalo internamente en el bucle
    
    # 3. Muestra un enunciado que explique para que N has sacado ese termino especifico

# %% [markdown]
# ## Bloque 3: Acumuladores - Sumatorias y Productorias

# %% [markdown]
# ### Sumatoria básica
# **Enunciado:** Calcular la suma de todos los números en un intervalo continuo.
# #### Sumatoria básica (simple)
# Suma 1 + 2 + 3 manualmente en una variable.

# %%
# 1. Haz que una variable contenga matematicamente 1 + 2 + 3

# 2. Imprime por pantalla su existencia

# %% [markdown]
# #### Sumatoria básica (con ciclos)
# Inicia `acumulador = 0`. Usa `for` para generar números del 1 al 10. Dentro, suma iterador al acumulador.

# %%
# 1. Crea el acumulador y dale valor inicial neutral 0

# 2. Pon un limite al ciclo range entre 1 y 10 inclusive

    # 3. Adiciona sobre la variable original el valor extraido del iterador en cada viaje

# 4. Al abandonar el nivel del bloque for, imprime la sumatoria total final

# %% [markdown]
# ### Productoria Factorial
# **Enunciado:** Multiplicar todos los enteros consecutivos hasta N.
# #### Productoria Factorial (simple)
# Calcula el factorial de 3 multiplicando `1 * 2 * 3` en una variable.

# %%
# 1. Escribe la formula de multiplicacion literal como constante guardada en tu variable

# 2. Revela el calculo usando print

# %% [markdown]
# #### Productoria Factorial (con ciclos)
# Inicia `producto = 1`. Pide un límite N. Usa el ciclo para multiplicar al acumulador.

# %%
# 1. Pide al usuario que defina el nivel de N

# 2. Asegura un elemento neutro de multiplicacion en el inicio (variable en 1)

# 3. Muevete usando for a lo largo de todos los eslabones hasta chocar con el input de arriba

    # 4. Sobreescribe la variable efectuando el calculo de multiplicacion

# 5. Ya finalizado, comparte la cantidad producida

# %% [markdown]
# ### Suma de una lista
# **Enunciado:** Obtener el total numérico de un arreglo existente.
# #### Suma de una lista (simple)
# Suma las posiciones `0` y `1` de forma manual.

# %%
# 1. Carga una lista con un par de boletas o gastos numericos 

# 2. Toma el indice 0 y el indice 1 y sumalos en total

# 3. Dispara la visualizacion de datos en texto

# %% [markdown]
# #### Suma de una lista (con ciclos)
# Recorre cada elemento de una lista grande sumándolos a tu propio acumulador.

# %%
# 1. Redacta tu lista de items con 4 precios o gastos variados enteros

# 2. Inicia la caja comun con 0

# 3. Accede uno a uno a los gastos viajando con el for item in coleccion

    # 4. Atrapa el numero del iterador presente y engordalo contra el total anterior

# 5. Termina la rutina imprimiendo por fuera la suma consolidada

# %% [markdown]
# ### Promedio Dinámico de Notas
# **Enunciado:** Calcular un promedio según lo que ingrese el usuario.
# #### Promedio Dinámico de Notas (simple)
# Pide 2 notas exactas, sumalas y divide entre 2.

# %%
# 1. Input para obtener el primer dato (en formato entero)

# 2. Input analogo para el segundo dato

# 3. Opera los bloques asegurando de usar los parentesis de suma antes de la division

# 4. Entrega el resultado de promedio

# %% [markdown]
# #### Promedio Dinámico de Notas (con ciclos)
# Pide cuántas notas hay. Haz un `for` de esa cantidad pidiendo y acumulando, luego divide por el total.

# %%
# 1. Pide un valor maximo de notas a revisar, de tipo int

# 2. Prepara la bolsa de sumas para almacenar la contabilidad de manera continua

# 3. Lanza el ciclo de iteracion for basado en range() operando el numero entregado al principio

    # 4. Obtiene interactivamente cada nota en este momento 
    
    # 5. Despues suma esta informacion directamente dentro del perimetro general de notas

# 6. Cae afuera del nivel de tabulacion for, ahora divide la suma acumulada completa frente a la cantidad estipulada

# 7. Y devela en pantalla cual es ese ratio de nivel global finalizado

# %% [markdown]
# ### Productoria condicional
# **Enunciado:** Multiplicar solo números que cumplan reglas.
# #### Productoria condicional (simple)
# Multiplica los primeros dos números pares manualmente.

# %%
# 1. Declara estatico de la productoria matematica basica de 2 y 4

# 2. Efectua con un print directo hacia esa declaracion

# %% [markdown]
# #### Productoria condicional (con ciclos)
# Acumulador multiplicativo en `1`. `for` del 1 al 10. Si el número es par, lo multiplicas al acumulador.

# %%
# 1. Elemento semilla multiplicativo en 1

# 2. Crea ese flujo para viajar entre las cotas del 1 inclusive, cerrando en 10 inclusive

    # 3. Cuestiona con logica if mediante operador modulo si es de naturaleza par
    
        # 4. Solo quienes aprueben seran multiplicados en su caja receptora

# 5. Demuestra los digitos obtenidos al clausurar el viaje

# %% [markdown]
# ### Ahorro progresivo
# **Enunciado:** Calcular crecimiento de una caja de dinero que evoluciona.
# #### Ahorro progresivo (simple)
# Suma una cuota estática a una caja dos veces manual.

# %%
# 1. Deja listo un fondo total partiendo de ceros

# 2. Inyecta 100 actualizando la misma variable

# 3. Vuelve a inyectar otros 100 de forma manual actualizando

# 4. Provee en texto tu registro monetario presente

# %% [markdown]
# #### Ahorro progresivo (con ciclos)
# Tu cuota inicia en 100 y se duplica por cada día que pasa. Itera 5 veces sumando la cuota a la caja y multiplicando la cuota por 2 para la vuelta siguiente.

# %%
# 1. Declara la cuota matriz configurada inicial de 100

# 2. Define y declara esa caja al vacio (0)

# 3. Construye un for de ciclo rapido por 5 veces sin indice especifico necesario (range generico)

    # 4. Manda el capital dinamico recien visto hacia la caja madre 
    
    # 5. Y sobreescribe el capital que cobrara manana duplicando exponencialmente por 2

# 6. Cierrate con el print total acumulado al terminar ese viaje cronologico

# %% [markdown]
# ### Sumatoria condicional de impares
# **Enunciado:** Sumar únicamente valores no divisibles por 2.
# #### Sumatoria condicional de impares (simple)
# Si un número ingresado es impar, guárdalo como total.

# %%
# 1. Atrapa un numero bajo el modo input() y convertidor en entero

# 2. Disena la canasta suma iniciada en blanco (0)

# 3. Cuestionalo en bloque condicional asegurandote que el modulo frente al 2 NO posea cero (!= 0)

    # 4. Integralo actualizando su recipiente contenedor

# 5. Muestra lo contenido de lo anterior en la consola

# %% [markdown]
# #### Sumatoria condicional de impares (con ciclos)
# Genera rango de 1 a 15, usa `if` para detectar si no es par y acumúlalo.

# %%
# 1. Asigna esta bandera variable partiendo natural de cero

# 2. Genera esa busqueda profunda extendida entre la linea base de 1 abarcando la cupula top de 14 finalizando de barrer (range 1 a 15)

    # 3. Impone condicionamiento if con el operador contrario al cero en su divisor analogo
    
        # 4. Captura al iterador calificado directo al fondo acumulador de su propio estado 

# 5. Ejecuta print revelando estetica de resultados a ultimo peldano

# %% [markdown]
# ### Contador estadístico
# **Enunciado:** Contar sujetos que cumplan condiciones en una lista.
# #### Contador estadístico (simple)
# Evalúa una sola nota manual si aprobó (>=4).

# %%
# 1. Instala nota constante manual numerica

# 2. Entrale duro verificando por logica basica if frente a la barrera tope minima permitida

    # 3. Y arroja confirmacion si cumplio el pase

# %% [markdown]
# #### Contador estadístico (con ciclos)
# Recorre una lista de notas. Si pasa la regla, suma a un contador `aprobados`.

# %%
# 1. Inscribe en una lista diversa calificaciones como un array [3, 5, ...]

# 2. Setea tu contador rastreador del exito en el inicio matematico vacio 

# 3. Muevete leyendo paso por paso extrayendo datos y colocandolos en la variable de paso local for in lista

    # 4. Mide con la barrera de >= a cuatro como if particular de iteracion 
    
        # 5. Adiciona matematicamente un (+1) sumando para seguir la caceria por validaciones logicas logradas  

# 6. Cierra al final sacando y entregando recuento total poblacional conseguido del estudio

# %% [markdown]
# ### Carrito de Compras Infinito
# **Enunciado:** Sumar infinitamente hasta la orden de alto (0).
# #### Carrito de Compras Infinito (simple)
# Pide 2 precios y suma.

# %%
# 1. Pide input estatico uno y dale cast de valor 

# 2. Hazlo idéntico por un segundo dato

# 3. Tira el resultado de ambos como totalizado en el codigo

# %% [markdown]
# #### Carrito de Compras Infinito (con ciclos)
# Pide un precio. Crea el `while precio != 0:`. Dentro, suma al acumulador y luego vuelve a pedir un precio antes del fin del bloque.

# %%
# 1. Arranca una base vacia numerica que atajara toda suma generada 

# 2. Escribe una primera recepcion de input preguntandole valor numerico bajo condicionante 'Cero apaga esto'

# 3. Abre las puertas usando iterador while con condicion explicita de que mientras aquel precio sea distinto de cero corra 

    # 4. Agrega los fondos del ultimo cobro a tu arca sumadora matriz central
    
    # 5. ¡Crucial! Repite la linea de codigo que pide un precio, antes de dejar que la marea del ciclo vuelva atras 

# 6. Imprime liberado del anclaje, su factura condensada despues del cierre de la terminal

# %% [markdown]
# ### Serie de Fibonacci
# **Enunciado:** El siguiente número es la suma de los dos de atrás.
# #### Serie de Fibonacci (simple)
# Empieza con a=0, b=1. Calcula el tercero manual.

# %%
# 1. Levanta los elementos fundamentales otorgandoles `a = 0` y simultaneamente `b = 1`

# 2. Produce el tercer elemento sumando algebraicamente estas iniciales guardandolas en una variante

# 3. Realiza exhibicion con los 3 unidos

# %% [markdown]
# #### Serie de Fibonacci (con ciclos)
# Genera 8 ciclos `for`. Calcula el tercero, avanza el valor de 'a' hacia 'b' y el de 'b' al nuevo para seguir rodando la matemática.

# %%
# 1. Instauracion identica de su dupla `a` con `b` de partida oficial

# 2. Haz alarde con un titular en pantalla

# 3. Dispara la rueda for repitiendo accionamiento 8 ocasiones

    # 4. Entrega e imprime tan solo `a` por vuelta (la que carga memoria pasada)
    
    # 5. Genera la incognita de la formula sumando los dos viejos elementos 
    
    # 6. Reacomoda para proxima movida la linea; haciendo a la letra `a` adquirir valor de `b`, y asi `b` se nutre con lo recien generado

# %% [markdown]
# ## Bloque 4: Búsquedas, Máximos y Mínimos

# %% [markdown]
# ### El número mayor
# **Enunciado:** Encontrar al rey de una lista por cuenta propia.
# #### El número mayor (simple)
# Compara 2 números exactos con `if / else`.

# %%
# 1. Dale a variable a un numero e igualemente un numero diferente a su contraria b 

# 2. Colisiona ambos valores estableciendo supremacia con operador >

    # 3. Y arroja confirmando la identidad ganadora 

# 4. Caso contrario invierte usando trampa else entregando b como rey alterno

# %% [markdown]
# #### El número mayor (con ciclos)
# Puntero de `mayor = 0`. Recorre la lista. Si el número actual vence al mayor histórico, lo sobreescribes.

# %%
# 1. Recluta unos cinco datos numericos en coleccion lista 

# 2. Implanta varita de historial mayor plantada en cero estricto de partida

# 3. Realiza rondines usando for en el interior del cuerpo analitico iterable completo

    # 4. Al chocar contra record historico comprueba victoria con su if respectivo
    
        # 5. Sustituye la corona y entrega el trono actualizando ese marcador a ganador nuevo que se hallo   

# 6. Cierra rutina dando noticia con el tope superior coronado

# %% [markdown]
# ### El número menor
# **Enunciado:** Rastrear el piso más bajo en colecciones.
# #### El número menor (simple)
# Usa lógica inversa de `a < b` manual.

# %%
# 1. Clona sistema de a y b 

# 2. Coloca comparacion apuntando aguja reversa hacia logica del <

    # 3. Expone el valor afortunado bajo condicion

# %% [markdown]
# #### El número menor (con ciclos)
# Empieza asumiendo que tu menor es un número exageradamente grande (ej: 9999). Si en el `for` hallas algo inferior a eso, reemplázalo.

# %%
# 1. Define lista portadora de datos de precios elevados y mixtos

# 2. Inventate un numero muy extremo altisimo, asi este actuara como senuelo para que todos puedan reemplazarle facil por ser absurdamente caro   

# 3. Patea todos con su for sacando la variable  

    # 4. Realiza medicion en embudo con su < if respecto al falso menor   
    
        # 5. Dale el derecho de reemplazar el costo historico  

# 6. Demuestra quien gano al finalizar

# %% [markdown]
# ### Buscando el objetivo (Waldo)
# **Enunciado:** Identificar la ubicación numérica de un valor.
# #### Buscando el objetivo (simple)
# Prueba si el primer elemento es Waldo con un `if`.

# %%
# 1. Forma lista introduciendo Waldo inicial en la puerta de la coleccion (indice cero) 

# 2. Evalualo cuestionando identicamente (==) hacia su index duro cero  

    # 3. Da fe que el elemento aparecia

# %% [markdown]
# #### Buscando el objetivo (con ciclos)
# Crea variable `posicion = -1` e `indice = 0`. Al recorrer la lista suma al índice y cuando haga match el valor guarda la posición. No rompas el bucle.

# %%
# 1. Arreglo numeroso de sujetos escondiendo la llave objetivo entre medias  

# 2. Asigna la brujula -1 como predeterminada (indica no rastro) y otra independiente sumadora con valor de ceros llamada indice    

# 3. Emprende caceria con for barriendo

    # 4. Aplica el lente lupa con su test si descubrimos correspondencia o match
    
        # 5. Haz calzar y guardar el dato de donde caia pasandole tu variante manual sumadora a la guardiana de posicion 
        
    # 6. Siempre se avanza y cuenta uno (+1), colocalo para continuar index sumado pase lo que pase adentro pero no bloqueado dentro del if 

# 7. Y finalmente devela a luz donde residia despues del recorrido

# %% [markdown]
# ### Mayor Histórico en Flujo Dinámico
# **Enunciado:** Averiguar el máximo pero cuando no sabemos cuántos datos se procesarán.
# #### Mayor Histórico (simple)
# Anida un if para tres variables de usuario.

# %%
# 1. Recopila primera interrogante int

# 2. Hazlo idéntico por una segunda 

# 3. Prepara que un capitan tome liderazgo forzandolo el valor uno 

# 4. Mira con reojo el segundo por if mayor 

    # 5. Sobreescribelo de calificar 

# 6. Entregalo completo

# %% [markdown]
# #### Mayor Histórico (con ciclos)
# Usa `while dato != -1`. Si es mayor que el record, se actualiza el record.

# %%
# 1. Fabrica tabla de maximos limpia iniciada  

# 2. Realiza recoleccion de puntaje (-1 de codigo de cortador)  

# 3. Exige a sus fronteras ciclicas accionar excluyendo al cortador de seguridad con su while  

    # 4. Pon filtro para reescribir trono  
    
        # 5. Subele el trofeo logico modificando el viejo 
        
    # 6. Vuelvele a presentar peticion de su dato pidiendo puntaje de fin de recorrido interno     

# 7. Despues que salga del loop, imprime quien ha vencido a lo largo del historial

# %% [markdown]
# ### El Segundo Al Mando
# **Enunciado:** Saber no solo el oro, sino la medalla de plata de una serie.
# #### El Segundo Al Mando (simple)
# Tienes 3 variables y determinas con lógica manual quién queda al medio.

# %%
# 1. Reparte las de puntajes prehechos diferentes 10 50 y 30 

# 2. Ejecuta un gran choque con condicionales and simultaneos indicando logicamente por descarte de comparaciones uno medio  

    # 3. Y arroja confirmando ese especificamente en pantalla

# %% [markdown]
# #### El Segundo Al Mando (con ciclos)
# Mantén 2 variables de puntaje en `0`. Recorre la lista con un `for`. Si es mayor al líder (max1), baja el líder a max2 y súbete a max1. Si solo es mayor a max2 (y menor a max1), actualiza max2.

# %%
# 1. Establece la matriz lista revuelta notas  

# 2. Acuna los records 1 y 2 neutros iniciales 

# 3. Abrele la jaula a tu for a escarbar la coleccion

    # 4. Mide con la barrera de maximo de frente de primer nivel, si destrona al mas fuerte primero debes proteger este desplazandolo hacia su nivel inferior max 2 antes de sobreescribirlo tu 
    
    # 5. Adiciona el caso contrario else y adentro otro if que de no golpear jefe superior de rebote pegue en maximo 2 al menos superandolo  
    
        # 6. Y asi sobreescribes ese 

# 7. Publica resultados duales

# %% [markdown]
# ## Bloque 5: Lógica de Primos y Divisores

# %% [markdown]
# ### Analizador de Divisores
# **Enunciado:** Mostrar quién puede dividir perfectamente a tu número.
# #### Analizador de Divisores (simple)
# Chequea el módulo a mano contra los valores del 1 al 3.

# %%
# 1. Define estatico el diez 

# 2. Usa chequeos consecutivos a mano if para saber que modulos resultan de cero exactos frente al uno dos y tres  

    # 3. Haz que se revelen si los logra concretar exitosos

# %% [markdown]
# #### Analizador de Divisores (con ciclos)
# Genera rango hasta tu propio número N. Si el módulo es cero, ese número actual del ciclo es un divisor válido.

# %%
# 1. Interroga cual se verificara al usuario int

# 2. Tira titular visual   

# 3. Gira la tuerca desde el inicio basal del 1 hacia el numero tope superior (recordar sumar extra al final inclusivo +1)

    # 4. Pon la evaluacion iterativa matematica del divisor contra aquel i modulo
    
        # 5. Imprime que fue exitosamente dividido

# %% [markdown]
# ### Acumulación de Divisores
# **Enunciado:** Solo obtener la cantidad total de divisores existentes.
# #### Acumulación de Divisores (simple)
# Evalúa uno solo y sube un contador.

# %%
# 1. Pon a andar el reloj de hallazgos desde el vacio 

# 2. Pruebale con logica al valor prehecho como un 15 evaluando al 5 de modulo y de cruzarlo agregas el ticket en suma simple de 1     

# 3. Notifica cual es este

# %% [markdown]
# #### Acumulación de Divisores (con ciclos)
# Sube el contador general en lugar de hacer print si la división da exacta en el `for`.

# %%
# 1. Solicita al incognito a revisar   

# 2. Crea pozo ciego a contar

# 3. Avanza por los peldanos matematicos inclusive el de meta  

    # 4. Pon el filtro del cero modulo 
    
        # 5. Sumale la pepita al fondo general del contador        

# 6. Entregalo de salida total condensado

# %% [markdown]
# ### El Número Primo
# **Enunciado:** Identificar la matemática de un primo (Divisible solo por 1 y si mismo).
# #### El Número Primo (simple)
# Descartar con un if de regla dura simple que no contenga divisibilidad por 2 o 3.

# %%
# 1. Atrapa un numero basico como 7 

# 2. Pasa filtro asumiendo regla de if doble que su division es != cero para ambos modulos basicos de dos y tres   

    # 3. Y arroja confirmando que tiene alta sospecha

# %% [markdown]
# #### El Número Primo (con ciclos)
# Construye bandera `es_primo = True`. `for` va desde `2` hasta el número evaluado (sin tocar los extremos legales). Si hay división 0, bajas la bandera a `False`.

# %%
# 1. Exige la prueba numeral int al usuario 

# 2. Clava la bandera confiando inicialmente ciega es_primo en su estado True

# 3. Recorre unicamente el intermedio peligroso de los numeros. Partiendo al dos para terminar exluyente sobre tu incognita original 

    # 4. En tu embudo iterativo haz trampa para desarmarlo tirandolo si un modulo llega a coincidir que vale 0    
    
        # 5. Quebrantalo para siempre bajando la estaca pasandola a False

# 6. En el estrato exterior al ciclo hazle lectura al resultado remanente validando if y else de cierre con la variable booleana resultando natural

# %% [markdown]
# ### Explorador de Primos
# **Enunciado:** Mapear en serie quién tiene la propiedad de primo.
# #### Explorador de Primos (simple)
# Imprime los 3 primeros de memoria.

# %%
# 1. Emite un dictado comun a pantalla enumerandolos 2 3 y 5 de frente

# %% [markdown]
# #### Explorador de Primos (con ciclos)
# Anidación. For principal recorre hasta N. Por cada valor, abre for interno usando bandera. Si es true al salir, imprimes.

# %%
# 1. Cierra limite fronterizo 

# 2. Dales titulo inicializador de contexto

# 3. Avanza en el nivel principal recorriendo tu bloque partiendo al dos inclusive limite top sumado (+1)

    # 4. Asegura clavar reseteando bandera inicial limpia es_primo recargada y optimista (True) para ese numero nuevo que se abrio   
    
    # 5. Adentra el segundo for, en base al primero iterativo secundario (i). Analogo desde 2 y exclusor de la variable numero exterior   
    
        # 6. Repite filtro castigador que derrumba condicion si modulo contra (i) vale ceros   
        
    # 7. Adosado a la estructura principal exterior, verifica el estado que logro subsistir del bucle destructivo para hacer honor y publicarlo

# %% [markdown]
# ### Sumatoria de Primos
# **Enunciado:** Sumar todo lo recolectado que cumpla norma primo.
# #### Sumatoria de Primos (simple)
# Suma 2 y 3 y 5 manual.

# %%
# 1. Recolectalos a los tres metiendolos a una simple constante estatica manual de suma

# 2. Imprime y avisa

# %% [markdown]
# #### Sumatoria de Primos (con ciclos)
# Igual a explorador pero suma en la caja fuerte global.

# %%
# 1. Exige margen superior meta   

# 2. Planta el banco mundial que recibe aportes vacio (0) 

# 3. Efectua toda el enjambre de anidaciones ciclicas de busqueda analizadas de 2 en cota de limite inclusive exterior e inferior adentro 

    # 4. Reclutalos por modulo descartando falsedad  
    
    # 5. El que paso sin embargo, no lo imprimas visual. Transfierelo y deposita incrementando el cofre acumulado final         

# 6. Descubre finalmente ante vista esa boveda de datos recolectados al salir

# %% [markdown]
# ## Bloque 6: Ciclos While de Estado Lógico

# %% [markdown]
# ### La Clave Correcta
# **Enunciado:** Proteger el flujo de sistema.
# #### La Clave Correcta (simple)
# Pide a un `if` de un único intento.

# %%
# 1. Trata input exigiendo seguridad 

# 2. Coteja en modo duro al 1234  

    # 3. Y arroja confirmando acceso o denegandole

# %% [markdown]
# #### La Clave Correcta (con ciclos)
# Aplica traba infinita con `while clave != objetivo`. Pide datos al interior para zafarse.

# %%
# 1. Forma estatica secreta prehecha  y vacia en nulo un intento 

# 2. Secuestra flujo en repeticion while operando MIENTRAS intento sea distinto que codigo correcto

    # 3. Carga por terminal de cliente el nuevo ingreso  
    
    # 4. Agregale el reproche en caso fallido si es distinto por malicia 

# 5. Remata fuera abriendo el control blindado

# %% [markdown]
# ### Límite de Intentos
# **Enunciado:** Impedir que intenten adivinar bloqueando todo a los pocos fallos.
# #### Límite de Intentos (simple)
# Confía y no pone bucle de error.

# %%
# 1. Toma un input con advertencia  

# 2. Determina con binario simple victoria if

# %% [markdown]
# #### Límite de Intentos (con ciclos)
# Traba `while intento != clave and fallas < 3`. Suma la falla por error.

# %%
# 1. Haz declaracion llave a perseguir, con contador cero de errores e intento vacio   

# 2. Obliga a cruzar la pasarela while bajo doble conjuncion de andar mal AND de que te queden caidas menores al 3

    # 3. Ingresa por input la chance nueva 
    
    # 4. Adicional pon el radar detector si ingreso mal actualiza las fallas en su caja penal (+1) y muestralo en pantalla 

# 5. Afuera de ese ambiente pon la lupa auditora; if adivino dale el trofeo else denega todo y da clausura

# %% [markdown]
# ### Construcción de frase
# **Enunciado:** Unir trozos hasta el texto final.
# #### Construcción de frase (simple)
# Une dos manuales en string.

# %%
# 1. Fija par de variantes textuales de palabras estandar 

# 2. Forma y consolida oraciones atando las con signo mas (+) interponiendo vacios artificiales     

# 3. Notifica esa amalgama

# %% [markdown]
# #### Construcción de frase (con ciclos)
# Añade al total `while palabra != salir`.

# %%
# 1. Vacia string de inicio larga que actuara de molde y vacia el intento   

# 2. Gira motor en while con la exclusion distinta al salir

    # 3. Captura texto pidiendo la palabra a amalgamar 
    
    # 4. Pone candado protector por if de que no era justo salir antes de inyectarlo en el molde   
    
        # 5. Adiciona como cadena de tren hacia variable original molde mas nuevo ingreso mas vacio  

# 6. Cierra rutina dando noticia con bloque textual logrado

# %% [markdown]
# ### Menú de opciones
# **Enunciado:** Hacer que un menú no muera hasta pedir fin.
# #### Menú de opciones (simple)
# Corre un `if` de un solo uso.

# %%
# 1. Da visualizacion inicial rapida   

# 2. Adquiere el boton tocado numerico

# 3. Ramificacalo evaluando segun si su input marca tal variante para reaccionar

# %% [markdown]
# #### Menú de opciones (con ciclos)
# Traba `while op != 3` que despliegue el menú reiteradas veces.

# %%
# 1. Da punto muerto (0) a tu indicador local     

# 2. Establece barrera while a no detener a no ser de cliquear el 3 especifico como salida  

    # 3. Haz cascada de texto presentacion de tu programa UI  
    
    # 4. Toma seleccion del pasajero  
    
    # 5. Abre ramificaciones que entreguen servicios del 1 o del 2 operativas 

# 6. Deja mensaje consolador exterior confirmando clausura al cerrar la aplicacion

# %% [markdown]
# ### Validación de Rango
# **Enunciado:** Imposibilitar matemáticamente valores perjudiciales.
# #### Validación de Rango (simple)
# Regla de if si excede.

# %%
# 1. Lee evaluado int   

# 2. Usa comparacion que detone OR indicando peligro de bajar inferior al uno O sobrepasar superior el 7

    # 3. Y arroja confirmando que causo alarma

# %% [markdown]
# #### Validación de Rango (con ciclos)
# Mantiene secuestrado al input `while var < 1 or var > 7`.

# %%
# 1. Instaura nota forzada en mala conducta predeterminada como un cero artificial

# 2. Levanta castigo while usando operador logico OR de manera que opere si peca abajo O si se excede arriba   

    # 3. Pidelo ingresando nota correctiva al castigado 
    
    # 4. Agudiza penalidad con repeticion de su mismo if para burlarse textualmente de su falla   

# 5. Termina la retencion y revela su dato libre por cumplir la exigencia

# %% [markdown]
# ### Adivina el Número Oculto
# **Enunciado:** Darle pistas al usuario sobre qué buscamos.
# #### Adivina el Número Oculto (simple)
# Evalúa 1 vez dictando ganador o no.

# %%
# 1. Esconde el misterio matematico y pide la chance

# 2. Cruza directo dictando victoria por exito O tirando perdida

# %% [markdown]
# #### Adivina el Número Oculto (con ciclos)
# La repetición se ejecuta si apostaste lo incorrecto. Pide internamente.

# %%
# 1. Esconde misterio en numero prehecho y arma intento basal vacio 

# 2. Mantente dentro del juego mientra no adivine la verdad por el distinto while

    # 3. Pidela chance de numero 
    
    # 4. Guia con ayuda si te quedaste chico pidiendo subir pista MAYOR
    
    # 5. Guia inversa pidiendo restar pista MENOR si pasaste tope    

# 6. Felicita victorioso la busqueda

# %% [markdown]
# ### La hucha de ahorros
# **Enunciado:** Continuar trabajando un fondo monetario hasta superar la cuota meta.
# #### La hucha de ahorros (simple)
# Tengo 500 y meta 1000. Regla dura simple.

# %%
# 1. Deja listo un estatico pobre 

# 2. Pruebalo tirandole una valla de if > meta ficticia y entrega feedback

# %% [markdown]
# #### La hucha de ahorros (con ciclos)
# Pide fondos `while` el acumulador no sobrepase esa pared de meta predefinida.

# %%
# 1. Dibuja esa meta a cruzar lejana alta e inicia chanchito contable al raz 

# 2. Opera por valla while que siga mientras no alcance el nivel necesario por logica menor    

    # 3. Ve mostrandole el conteo a modo de avance al cliente 
    
    # 4. Requiere y sumale la nueva donacion iterativa al chanchito madre     

# 5. Grita exito por los cielos al salir por rebasar al tope marcado
