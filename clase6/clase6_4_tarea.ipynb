# %% [markdown]
# ### Ejercicio 1: Filtrado de Números Pares
#
# **Descripción del problema:**
# Crea un programa que solicite al usuario ingresar 5 números enteros, uno por separado. El programa debe evaluar cada número y agregar a una lista **únicamente** aquellos que sean pares. Al finalizar, muestra la lista resultante en pantalla.
#
# **Hint (El operador módulo `%`):**
# El operador `%` en Python se utiliza para obtener el resto (o residuo) de una división matemática.
# - `10 % 2` da como resultado `0` (porque 10 dividido en 2 es exacto).
# - `7 % 2` da como resultado `1` (porque 7 dividido en 2 es 3, y sobra 1).
# - `15 % 4` da como resultado `3` (porque 15 dividido en 4 es 3, y sobran 3).
#
# **Ejemplo de ejecución esperada:**
# ```text
# Ingrese el número 1: 3
# Ingrese el número 2: 8
# Ingrese el número 3: 5
# Ingrese el número 4: 12
# Ingrese el número 5: 7
#
# Lista final de números pares: [8, 12]
# ```

# %%
# Escribe aquí tu código para el Ejercicio 1

# %% [markdown]
# ### Ejercicio 2: Lista en Ascenso o Descenso Según el Usuario
#
# **Descripción del problema:**
# Crea un programa que:
# - Pida **dos números al usuario**.
# - Si el **primer número es mayor que el segundo**, genera una lista en **descenso**.
# - Si el **primer número es menor que el segundo**, genera una lista en **ascenso**.
# - Usa la función `range()` con el **paso adecuado** (positivo o negativo).
# - Muestra la **lista generada** por pantalla.
#
# *(Nota: Recuerda el comportamiento por defecto de `range()` donde el número final es excluyente).*
#
# **Ejemplo de ejecución esperada (Ascenso):**
# ```text
# Ingrese el primer número: 3
# Ingrese el segundo número: 8
#
# Lista generada: [3, 4, 5, 6, 7]
# ```
#
# **Ejemplo de ejecución esperada (Descenso):**
# ```text
# Ingrese el primer número: 10
# Ingrese el segundo número: 4
#
# Lista generada: [10, 9, 8, 7, 6, 5]
# ```

# %%
# Escribe aquí tu código para el Ejercicio 2
